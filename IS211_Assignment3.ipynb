# %%
import re
import argparse
import csv
import urllib2

url = 'http://s3.amazonaws.com/cuny-is211-spring2015/weblog.csv'
response = urllib2.urlopen(url)
cr = csv.reader(response)

image_hits = 0
browser_hits = 0
columns = 0

IE = ['Internet Explorer', 0]
CHROME = ['Google Chrome', 0]
FIREFOX = ['Mozilla Firefox', 0]
SAFARI = ['Safari', 0]

for line in cr:
    columns += 1
    if re.search("Firefox", line[2], re.I):
        FIREFOX[1] += 1
    elif re.search(r"MSIE", line[2]):
        IE[1] += 1
    elif re.search(r"Chrome", line[2]):
        CHROME[1] += 1
    elif re.search(r"Safari", line[2]) and not re.search("Chrome", line[2]):
        SAFARI[1] += 1
    if re.search(r"jpe?g|JPE?G|png|PNG|gif|GIF", line[0]):
        image_hits += 1
        
    image_hits_counter = (float(image_hits) / columns) * 100
    
    browser_hits = (CHROME, IE, SAFARI, FIREFOX)
    
    pop_count = 0
    
    pop_browser = ' '
    
    for b in browser_hits:
        if b[1] > pop_count:
            pop_count = b[1]
            pop_browser = b[0]
        else:
            continue
    stats = ('There were {} page hits today, image requests account for {}% of '
            'hits. \n{} has the most hits with {}.').format(columns, image_hits_counter, pop_browser, pop_count)
    

    print stats
# Out:
# There were 1 page hits today, image requests account for 0.0% of hits.
# Mozilla Firefox has the most hits with 1.
# There were 2 page hits today, image requests account for 50.0% of hits.
# Google Chrome has the most hits with 1.
# There were 3 page hits today, image requests account for 66.6666666667% of hits.
# Mozilla Firefox has the most hits with 2.
# There were 4 page hits today, image requests account for 75.0% of hits.
# Mozilla Firefox has the most hits with 2.
# There were 5 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 2.
# There were 6 page hits today, image requests account for 83.3333333333% of hits.
# Google Chrome has the most hits with 2.
# There were 7 page hits today, image requests account for 85.7142857143% of hits.
# Google Chrome has the most hits with 3.
# There were 8 page hits today, image requests account for 75.0% of hits.
# Google Chrome has the most hits with 4.
# There were 9 page hits today, image requests account for 66.6666666667% of hits.
# Google Chrome has the most hits with 5.
# There were 10 page hits today, image requests account for 70.0% of hits.
# Google Chrome has the most hits with 6.
# There were 11 page hits today, image requests account for 72.7272727273% of hits.
# Google Chrome has the most hits with 6.
# There were 12 page hits today, image requests account for 75.0% of hits.
# Google Chrome has the most hits with 7.
# There were 13 page hits today, image requests account for 76.9230769231% of hits.
# Google Chrome has the most hits with 7.
# There were 14 page hits today, image requests account for 78.5714285714% of hits.
# Google Chrome has the most hits with 7.
# There were 15 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 7.
# There were 16 page hits today, image requests account for 81.25% of hits.
# Google Chrome has the most hits with 8.
# There were 17 page hits today, image requests account for 82.3529411765% of hits.
# Google Chrome has the most hits with 8.
# There were 18 page hits today, image requests account for 77.7777777778% of hits.
# Google Chrome has the most hits with 9.
# There were 19 page hits today, image requests account for 78.9473684211% of hits.
# Google Chrome has the most hits with 9.
# There were 20 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 10.
# There were 21 page hits today, image requests account for 80.9523809524% of hits.
# Google Chrome has the most hits with 11.
# There were 22 page hits today, image requests account for 81.8181818182% of hits.
# Google Chrome has the most hits with 12.
# There were 23 page hits today, image requests account for 82.6086956522% of hits.
# Google Chrome has the most hits with 13.
# There were 24 page hits today, image requests account for 83.3333333333% of hits.
# Google Chrome has the most hits with 13.
# There were 25 page hits today, image requests account for 84.0% of hits.
# Google Chrome has the most hits with 13.
# There were 26 page hits today, image requests account for 84.6153846154% of hits.
# Google Chrome has the most hits with 14.
# There were 27 page hits today, image requests account for 85.1851851852% of hits.
# Google Chrome has the most hits with 15.
# There were 28 page hits today, image requests account for 85.7142857143% of hits.
# Google Chrome has the most hits with 15.
# There were 29 page hits today, image requests account for 86.2068965517% of hits.
# Google Chrome has the most hits with 16.
# There were 30 page hits today, image requests account for 86.6666666667% of hits.
# Google Chrome has the most hits with 17.
# There were 31 page hits today, image requests account for 87.0967741935% of hits.
# Google Chrome has the most hits with 18.
# There were 32 page hits today, image requests account for 87.5% of hits.
# Google Chrome has the most hits with 18.
# There were 33 page hits today, image requests account for 84.8484848485% of hits.
# Google Chrome has the most hits with 19.
# There were 34 page hits today, image requests account for 85.2941176471% of hits.
# Google Chrome has the most hits with 20.
# There were 35 page hits today, image requests account for 85.7142857143% of hits.
# Google Chrome has the most hits with 21.
# There were 36 page hits today, image requests account for 86.1111111111% of hits.
# Google Chrome has the most hits with 22.
# There were 37 page hits today, image requests account for 83.7837837838% of hits.
# Google Chrome has the most hits with 22.
# There were 38 page hits today, image requests account for 84.2105263158% of hits.
# Google Chrome has the most hits with 23.
# There were 39 page hits today, image requests account for 84.6153846154% of hits.
# Google Chrome has the most hits with 23.
# There were 40 page hits today, image requests account for 85.0% of hits.
# Google Chrome has the most hits with 24.
# There were 41 page hits today, image requests account for 82.9268292683% of hits.
# Google Chrome has the most hits with 25.
# There were 42 page hits today, image requests account for 83.3333333333% of hits.
# Google Chrome has the most hits with 25.
# There were 43 page hits today, image requests account for 81.3953488372% of hits.
# Google Chrome has the most hits with 25.
# There were 44 page hits today, image requests account for 81.8181818182% of hits.
# Google Chrome has the most hits with 25.
# There were 45 page hits today, image requests account for 82.2222222222% of hits.
# Google Chrome has the most hits with 26.
# There were 46 page hits today, image requests account for 82.6086956522% of hits.
# Google Chrome has the most hits with 26.
# There were 47 page hits today, image requests account for 82.9787234043% of hits.
# Google Chrome has the most hits with 26.
# There were 48 page hits today, image requests account for 81.25% of hits.
# Google Chrome has the most hits with 26.
# There were 49 page hits today, image requests account for 79.5918367347% of hits.
# Google Chrome has the most hits with 26.
# There were 50 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 27.
# There were 51 page hits today, image requests account for 80.3921568627% of hits.
# Google Chrome has the most hits with 27.
# There were 52 page hits today, image requests account for 78.8461538462% of hits.
# Google Chrome has the most hits with 27.
# There were 53 page hits today, image requests account for 79.2452830189% of hits.
# Google Chrome has the most hits with 27.
# There were 54 page hits today, image requests account for 79.6296296296% of hits.
# Google Chrome has the most hits with 27.
# There were 55 page hits today, image requests account for 78.1818181818% of hits.
# Google Chrome has the most hits with 27.
# There were 56 page hits today, image requests account for 78.5714285714% of hits.
# Google Chrome has the most hits with 28.
# There were 57 page hits today, image requests account for 77.1929824561% of hits.
# Google Chrome has the most hits with 28.
# There were 58 page hits today, image requests account for 77.5862068966% of hits.
# Google Chrome has the most hits with 28.
# There were 59 page hits today, image requests account for 77.9661016949% of hits.
# Google Chrome has the most hits with 29.
# There were 60 page hits today, image requests account for 78.3333333333% of hits.
# Google Chrome has the most hits with 29.
# There were 61 page hits today, image requests account for 78.6885245902% of hits.
# Google Chrome has the most hits with 29.
# There were 62 page hits today, image requests account for 79.0322580645% of hits.
# Google Chrome has the most hits with 29.
# There were 63 page hits today, image requests account for 77.7777777778% of hits.
# Google Chrome has the most hits with 30.
# There were 64 page hits today, image requests account for 78.125% of hits.
# Google Chrome has the most hits with 30.
# There were 65 page hits today, image requests account for 78.4615384615% of hits.
# Google Chrome has the most hits with 30.
# There were 66 page hits today, image requests account for 78.7878787879% of hits.
# Google Chrome has the most hits with 30.
# There were 67 page hits today, image requests account for 79.1044776119% of hits.
# Google Chrome has the most hits with 31.
# There were 68 page hits today, image requests account for 79.4117647059% of hits.
# Google Chrome has the most hits with 32.
# There were 69 page hits today, image requests account for 79.7101449275% of hits.
# Google Chrome has the most hits with 32.
# There were 70 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 32.
# There were 71 page hits today, image requests account for 80.2816901408% of hits.
# Google Chrome has the most hits with 32.
# There were 72 page hits today, image requests account for 80.5555555556% of hits.
# Google Chrome has the most hits with 33.
# There were 73 page hits today, image requests account for 79.4520547945% of hits.
# Google Chrome has the most hits with 33.
# There were 74 page hits today, image requests account for 79.7297297297% of hits.
# Google Chrome has the most hits with 34.
# There were 75 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 34.
# There were 76 page hits today, image requests account for 80.2631578947% of hits.
# Google Chrome has the most hits with 34.
# There were 77 page hits today, image requests account for 80.5194805195% of hits.
# Google Chrome has the most hits with 34.
# There were 78 page hits today, image requests account for 80.7692307692% of hits.
# Google Chrome has the most hits with 35.
# There were 79 page hits today, image requests account for 81.0126582278% of hits.
# Google Chrome has the most hits with 36.
# There were 80 page hits today, image requests account for 81.25% of hits.
# Google Chrome has the most hits with 37.
# There were 81 page hits today, image requests account for 81.4814814815% of hits.
# Google Chrome has the most hits with 37.
# There were 82 page hits today, image requests account for 81.7073170732% of hits.
# Google Chrome has the most hits with 38.
# There were 83 page hits today, image requests account for 81.9277108434% of hits.
# Google Chrome has the most hits with 38.
# There were 84 page hits today, image requests account for 82.1428571429% of hits.
# Google Chrome has the most hits with 38.
# There were 85 page hits today, image requests account for 82.3529411765% of hits.
# Google Chrome has the most hits with 38.
# There were 86 page hits today, image requests account for 81.3953488372% of hits.
# Google Chrome has the most hits with 39.
# There were 87 page hits today, image requests account for 81.6091954023% of hits.
# Google Chrome has the most hits with 39.
# There were 88 page hits today, image requests account for 81.8181818182% of hits.
# Google Chrome has the most hits with 39.
# There were 89 page hits today, image requests account for 82.0224719101% of hits.
# Google Chrome has the most hits with 39.
# There were 90 page hits today, image requests account for 82.2222222222% of hits.
# Google Chrome has the most hits with 40.
# There were 91 page hits today, image requests account for 82.4175824176% of hits.
# Google Chrome has the most hits with 40.
# There were 92 page hits today, image requests account for 82.6086956522% of hits.
# Google Chrome has the most hits with 41.
# There were 93 page hits today, image requests account for 82.7956989247% of hits.
# Google Chrome has the most hits with 42.
# There were 94 page hits today, image requests account for 82.9787234043% of hits.
# Google Chrome has the most hits with 43.
# There were 95 page hits today, image requests account for 83.1578947368% of hits.
# Google Chrome has the most hits with 43.
# There were 96 page hits today, image requests account for 82.2916666667% of hits.
# Google Chrome has the most hits with 43.
# There were 97 page hits today, image requests account for 81.4432989691% of hits.
# Google Chrome has the most hits with 44.
# There were 98 page hits today, image requests account for 81.6326530612% of hits.
# Google Chrome has the most hits with 44.
# There were 99 page hits today, image requests account for 81.8181818182% of hits.
# Google Chrome has the most hits with 44.
# There were 100 page hits today, image requests account for 82.0% of hits.
# Google Chrome has the most hits with 44.
# There were 101 page hits today, image requests account for 82.1782178218% of hits.
# Google Chrome has the most hits with 44.
# There were 102 page hits today, image requests account for 82.3529411765% of hits.
# Google Chrome has the most hits with 45.
# There were 103 page hits today, image requests account for 82.5242718447% of hits.
# Google Chrome has the most hits with 45.
# There were 104 page hits today, image requests account for 82.6923076923% of hits.
# Google Chrome has the most hits with 46.
# There were 105 page hits today, image requests account for 82.8571428571% of hits.
# Google Chrome has the most hits with 46.
# There were 106 page hits today, image requests account for 83.0188679245% of hits.
# Google Chrome has the most hits with 46.
# There were 107 page hits today, image requests account for 83.1775700935% of hits.
# Google Chrome has the most hits with 47.
# There were 108 page hits today, image requests account for 83.3333333333% of hits.
# Google Chrome has the most hits with 48.
# There were 109 page hits today, image requests account for 82.5688073394% of hits.
# Google Chrome has the most hits with 49.
# There were 110 page hits today, image requests account for 82.7272727273% of hits.
# Google Chrome has the most hits with 49.
# There were 111 page hits today, image requests account for 82.8828828829% of hits.
# Google Chrome has the most hits with 50.
# There were 112 page hits today, image requests account for 83.0357142857% of hits.
# Google Chrome has the most hits with 51.
# There were 113 page hits today, image requests account for 83.185840708% of hits.
# Google Chrome has the most hits with 51.
# There were 114 page hits today, image requests account for 83.3333333333% of hits.
# Google Chrome has the most hits with 52.
# There were 115 page hits today, image requests account for 82.6086956522% of hits.
# Google Chrome has the most hits with 52.
# There were 116 page hits today, image requests account for 82.7586206897% of hits.
# Google Chrome has the most hits with 53.
# There were 117 page hits today, image requests account for 82.905982906% of hits.
# Google Chrome has the most hits with 54.
# There were 118 page hits today, image requests account for 83.0508474576% of hits.
# Google Chrome has the most hits with 54.
# There were 119 page hits today, image requests account for 83.1932773109% of hits.
# Google Chrome has the most hits with 54.
# There were 120 page hits today, image requests account for 83.3333333333% of hits.
# Google Chrome has the most hits with 55.
# There were 121 page hits today, image requests account for 83.4710743802% of hits.
# Google Chrome has the most hits with 56.
# There were 122 page hits today, image requests account for 83.606557377% of hits.
# Google Chrome has the most hits with 56.
# There were 123 page hits today, image requests account for 83.7398373984% of hits.
# Google Chrome has the most hits with 56.
# There were 124 page hits today, image requests account for 83.8709677419% of hits.
# Google Chrome has the most hits with 57.
# There were 125 page hits today, image requests account for 84.0% of hits.
# Google Chrome has the most hits with 58.
# There were 126 page hits today, image requests account for 84.126984127% of hits.
# Google Chrome has the most hits with 59.
# There were 127 page hits today, image requests account for 84.2519685039% of hits.
# Google Chrome has the most hits with 59.
# There were 128 page hits today, image requests account for 84.375% of hits.
# Google Chrome has the most hits with 60.
# There were 129 page hits today, image requests account for 84.496124031% of hits.
# Google Chrome has the most hits with 61.
# There were 130 page hits today, image requests account for 84.6153846154% of hits.
# Google Chrome has the most hits with 61.
# There were 131 page hits today, image requests account for 83.9694656489% of hits.
# Google Chrome has the most hits with 62.
# There were 132 page hits today, image requests account for 84.0909090909% of hits.
# Google Chrome has the most hits with 63.
# There were 133 page hits today, image requests account for 84.2105263158% of hits.
# Google Chrome has the most hits with 64.
# There were 134 page hits today, image requests account for 84.328358209% of hits.
# Google Chrome has the most hits with 64.
# There were 135 page hits today, image requests account for 84.4444444444% of hits.
# Google Chrome has the most hits with 64.
# There were 136 page hits today, image requests account for 83.8235294118% of hits.
# Google Chrome has the most hits with 65.
# There were 137 page hits today, image requests account for 83.2116788321% of hits.
# Google Chrome has the most hits with 65.
# There were 138 page hits today, image requests account for 82.6086956522% of hits.
# Google Chrome has the most hits with 65.
# There were 139 page hits today, image requests account for 82.7338129496% of hits.
# Google Chrome has the most hits with 66.
# There were 140 page hits today, image requests account for 82.1428571429% of hits.
# Google Chrome has the most hits with 66.
# There were 141 page hits today, image requests account for 82.2695035461% of hits.
# Google Chrome has the most hits with 66.
# There were 142 page hits today, image requests account for 81.6901408451% of hits.
# Google Chrome has the most hits with 66.
# There were 143 page hits today, image requests account for 81.8181818182% of hits.
# Google Chrome has the most hits with 66.
# There were 144 page hits today, image requests account for 81.9444444444% of hits.
# Google Chrome has the most hits with 66.
# There were 145 page hits today, image requests account for 81.3793103448% of hits.
# Google Chrome has the most hits with 66.
# There were 146 page hits today, image requests account for 80.8219178082% of hits.
# Google Chrome has the most hits with 67.
# There were 147 page hits today, image requests account for 80.9523809524% of hits.
# Google Chrome has the most hits with 67.
# There were 148 page hits today, image requests account for 80.4054054054% of hits.
# Google Chrome has the most hits with 68.
# There were 149 page hits today, image requests account for 80.5369127517% of hits.
# Google Chrome has the most hits with 69.
# There were 150 page hits today, image requests account for 80.6666666667% of hits.
# Google Chrome has the most hits with 69.
# There were 151 page hits today, image requests account for 80.7947019868% of hits.
# Google Chrome has the most hits with 70.
# There were 152 page hits today, image requests account for 80.9210526316% of hits.
# Google Chrome has the most hits with 71.
# There were 153 page hits today, image requests account for 80.3921568627% of hits.
# Google Chrome has the most hits with 71.
# There were 154 page hits today, image requests account for 80.5194805195% of hits.
# Google Chrome has the most hits with 72.
# There were 155 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 72.
# There were 156 page hits today, image requests account for 80.1282051282% of hits.
# Google Chrome has the most hits with 73.
# There were 157 page hits today, image requests account for 80.2547770701% of hits.
# Google Chrome has the most hits with 73.
# There were 158 page hits today, image requests account for 80.3797468354% of hits.
# Google Chrome has the most hits with 73.
# There were 159 page hits today, image requests account for 79.8742138365% of hits.
# Google Chrome has the most hits with 74.
# There were 160 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 75.
# There were 161 page hits today, image requests account for 80.1242236025% of hits.
# Google Chrome has the most hits with 75.
# There were 162 page hits today, image requests account for 79.6296296296% of hits.
# Google Chrome has the most hits with 75.
# There were 163 page hits today, image requests account for 79.1411042945% of hits.
# Google Chrome has the most hits with 76.
# There were 164 page hits today, image requests account for 79.2682926829% of hits.
# Google Chrome has the most hits with 77.
# There were 165 page hits today, image requests account for 79.3939393939% of hits.
# Google Chrome has the most hits with 77.
# There were 166 page hits today, image requests account for 79.5180722892% of hits.
# Google Chrome has the most hits with 77.
# There were 167 page hits today, image requests account for 79.0419161677% of hits.
# Google Chrome has the most hits with 77.
# There were 168 page hits today, image requests account for 79.1666666667% of hits.
# Google Chrome has the most hits with 77.
# There were 169 page hits today, image requests account for 78.6982248521% of hits.
# Google Chrome has the most hits with 78.
# There were 170 page hits today, image requests account for 78.8235294118% of hits.
# Google Chrome has the most hits with 78.
# There were 171 page hits today, image requests account for 78.3625730994% of hits.
# Google Chrome has the most hits with 79.
# There were 172 page hits today, image requests account for 78.488372093% of hits.
# Google Chrome has the most hits with 80.
# There were 173 page hits today, image requests account for 78.612716763% of hits.
# Google Chrome has the most hits with 81.
# There were 174 page hits today, image requests account for 78.7356321839% of hits.
# Google Chrome has the most hits with 82.
# There were 175 page hits today, image requests account for 78.8571428571% of hits.
# Google Chrome has the most hits with 83.
# There were 176 page hits today, image requests account for 78.9772727273% of hits.
# Google Chrome has the most hits with 83.
# There were 177 page hits today, image requests account for 79.0960451977% of hits.
# Google Chrome has the most hits with 84.
# There were 178 page hits today, image requests account for 79.2134831461% of hits.
# Google Chrome has the most hits with 85.
# There were 179 page hits today, image requests account for 78.7709497207% of hits.
# Google Chrome has the most hits with 85.
# There were 180 page hits today, image requests account for 78.8888888889% of hits.
# Google Chrome has the most hits with 85.
# There were 181 page hits today, image requests account for 78.453038674% of hits.
# Google Chrome has the most hits with 85.
# There were 182 page hits today, image requests account for 78.5714285714% of hits.
# Google Chrome has the most hits with 85.
# There were 183 page hits today, image requests account for 78.6885245902% of hits.
# Google Chrome has the most hits with 85.
# There were 184 page hits today, image requests account for 78.8043478261% of hits.
# Google Chrome has the most hits with 85.
# There were 185 page hits today, image requests account for 78.9189189189% of hits.
# Google Chrome has the most hits with 86.
# There were 186 page hits today, image requests account for 79.0322580645% of hits.
# Google Chrome has the most hits with 86.
# There were 187 page hits today, image requests account for 79.1443850267% of hits.
# Google Chrome has the most hits with 87.
# There were 188 page hits today, image requests account for 79.2553191489% of hits.
# Google Chrome has the most hits with 88.
# There were 189 page hits today, image requests account for 79.3650793651% of hits.
# Google Chrome has the most hits with 89.
# There were 190 page hits today, image requests account for 79.4736842105% of hits.
# Google Chrome has the most hits with 89.
# There were 191 page hits today, image requests account for 79.057591623% of hits.
# Google Chrome has the most hits with 89.
# There were 192 page hits today, image requests account for 78.6458333333% of hits.
# Google Chrome has the most hits with 89.
# There were 193 page hits today, image requests account for 78.7564766839% of hits.
# Google Chrome has the most hits with 89.
# There were 194 page hits today, image requests account for 78.3505154639% of hits.
# Google Chrome has the most hits with 89.
# There were 195 page hits today, image requests account for 78.4615384615% of hits.
# Google Chrome has the most hits with 89.
# There were 196 page hits today, image requests account for 78.5714285714% of hits.
# Google Chrome has the most hits with 89.
# There were 197 page hits today, image requests account for 78.6802030457% of hits.
# Google Chrome has the most hits with 90.
# There were 198 page hits today, image requests account for 78.2828282828% of hits.
# Google Chrome has the most hits with 90.
# There were 199 page hits today, image requests account for 78.391959799% of hits.
# Google Chrome has the most hits with 91.
# There were 200 page hits today, image requests account for 78.5% of hits.
# Google Chrome has the most hits with 91.
# There were 201 page hits today, image requests account for 78.1094527363% of hits.
# Google Chrome has the most hits with 91.
# There were 202 page hits today, image requests account for 78.2178217822% of hits.
# Google Chrome has the most hits with 91.
# There were 203 page hits today, image requests account for 77.8325123153% of hits.
# Google Chrome has the most hits with 92.
# There were 204 page hits today, image requests account for 77.9411764706% of hits.
# Google Chrome has the most hits with 93.
# There were 205 page hits today, image requests account for 78.0487804878% of hits.
# Google Chrome has the most hits with 94.
# There were 206 page hits today, image requests account for 78.1553398058% of hits.
# Google Chrome has the most hits with 94.
# There were 207 page hits today, image requests account for 78.2608695652% of hits.
# Google Chrome has the most hits with 94.
# There were 208 page hits today, image requests account for 78.3653846154% of hits.
# Google Chrome has the most hits with 94.
# There were 209 page hits today, image requests account for 78.4688995215% of hits.
# Google Chrome has the most hits with 94.
# There were 210 page hits today, image requests account for 78.5714285714% of hits.
# Google Chrome has the most hits with 95.
# There were 211 page hits today, image requests account for 78.672985782% of hits.
# Google Chrome has the most hits with 95.
# There were 212 page hits today, image requests account for 78.7735849057% of hits.
# Google Chrome has the most hits with 95.
# There were 213 page hits today, image requests account for 78.8732394366% of hits.
# Google Chrome has the most hits with 95.
# There were 214 page hits today, image requests account for 78.9719626168% of hits.
# Google Chrome has the most hits with 95.
# There were 215 page hits today, image requests account for 78.6046511628% of hits.
# Google Chrome has the most hits with 95.
# There were 216 page hits today, image requests account for 78.7037037037% of hits.
# Google Chrome has the most hits with 95.
# There were 217 page hits today, image requests account for 78.801843318% of hits.
# Google Chrome has the most hits with 95.
# There were 218 page hits today, image requests account for 78.8990825688% of hits.
# Google Chrome has the most hits with 96.
# There were 219 page hits today, image requests account for 78.99543379% of hits.
# Google Chrome has the most hits with 96.
# There were 220 page hits today, image requests account for 79.0909090909% of hits.
# Google Chrome has the most hits with 96.
# There were 221 page hits today, image requests account for 79.185520362% of hits.
# Google Chrome has the most hits with 96.
# There were 222 page hits today, image requests account for 79.2792792793% of hits.
# Google Chrome has the most hits with 97.
# There were 223 page hits today, image requests account for 79.3721973094% of hits.
# Google Chrome has the most hits with 97.
# There were 224 page hits today, image requests account for 79.4642857143% of hits.
# Google Chrome has the most hits with 97.
# There were 225 page hits today, image requests account for 79.5555555556% of hits.
# Google Chrome has the most hits with 98.
# There were 226 page hits today, image requests account for 79.6460176991% of hits.
# Google Chrome has the most hits with 98.
# There were 227 page hits today, image requests account for 79.7356828194% of hits.
# Google Chrome has the most hits with 98.
# There were 228 page hits today, image requests account for 79.8245614035% of hits.
# Google Chrome has the most hits with 99.
# There were 229 page hits today, image requests account for 79.9126637555% of hits.
# Google Chrome has the most hits with 99.
# There were 230 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 99.
# There were 231 page hits today, image requests account for 80.0865800866% of hits.
# Google Chrome has the most hits with 99.
# There were 232 page hits today, image requests account for 79.7413793103% of hits.
# Google Chrome has the most hits with 99.
# There were 233 page hits today, image requests account for 79.3991416309% of hits.
# Google Chrome has the most hits with 100.
# There were 234 page hits today, image requests account for 79.4871794872% of hits.
# Google Chrome has the most hits with 101.
# There were 235 page hits today, image requests account for 79.5744680851% of hits.
# Google Chrome has the most hits with 101.
# There were 236 page hits today, image requests account for 79.6610169492% of hits.
# Google Chrome has the most hits with 102.
# There were 237 page hits today, image requests account for 79.746835443% of hits.
# Google Chrome has the most hits with 102.
# There were 238 page hits today, image requests account for 79.8319327731% of hits.
# Google Chrome has the most hits with 103.
# There were 239 page hits today, image requests account for 79.9163179916% of hits.
# Google Chrome has the most hits with 103.
# There were 240 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 104.
# There were 241 page hits today, image requests account for 80.0829875519% of hits.
# Google Chrome has the most hits with 104.
# There were 242 page hits today, image requests account for 80.1652892562% of hits.
# Google Chrome has the most hits with 105.
# There were 243 page hits today, image requests account for 79.8353909465% of hits.
# Google Chrome has the most hits with 106.
# There were 244 page hits today, image requests account for 79.5081967213% of hits.
# Google Chrome has the most hits with 107.
# There were 245 page hits today, image requests account for 79.5918367347% of hits.
# Google Chrome has the most hits with 107.
# There were 246 page hits today, image requests account for 79.674796748% of hits.
# Google Chrome has the most hits with 108.
# There were 247 page hits today, image requests account for 79.7570850202% of hits.
# Google Chrome has the most hits with 109.
# There were 248 page hits today, image requests account for 79.435483871% of hits.
# Google Chrome has the most hits with 109.
# There were 249 page hits today, image requests account for 79.5180722892% of hits.
# Google Chrome has the most hits with 109.
# There were 250 page hits today, image requests account for 79.6% of hits.
# Google Chrome has the most hits with 109.
# There were 251 page hits today, image requests account for 79.6812749004% of hits.
# Google Chrome has the most hits with 109.
# There were 252 page hits today, image requests account for 79.7619047619% of hits.
# Google Chrome has the most hits with 109.
# There were 253 page hits today, image requests account for 79.8418972332% of hits.
# Google Chrome has the most hits with 110.
# There were 254 page hits today, image requests account for 79.9212598425% of hits.
# Google Chrome has the most hits with 110.
# There were 255 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 110.
# There were 256 page hits today, image requests account for 80.078125% of hits.
# Google Chrome has the most hits with 111.
# There were 257 page hits today, image requests account for 80.1556420233% of hits.
# Google Chrome has the most hits with 111.
# There were 258 page hits today, image requests account for 80.2325581395% of hits.
# Google Chrome has the most hits with 111.
# There were 259 page hits today, image requests account for 80.3088803089% of hits.
# Google Chrome has the most hits with 111.
# There were 260 page hits today, image requests account for 80.3846153846% of hits.
# Google Chrome has the most hits with 111.
# There were 261 page hits today, image requests account for 80.4597701149% of hits.
# Google Chrome has the most hits with 111.
# There were 262 page hits today, image requests account for 80.534351145% of hits.
# Google Chrome has the most hits with 112.
# There were 263 page hits today, image requests account for 80.608365019% of hits.
# Google Chrome has the most hits with 113.
# There were 264 page hits today, image requests account for 80.303030303% of hits.
# Google Chrome has the most hits with 113.
# There were 265 page hits today, image requests account for 80.3773584906% of hits.
# Google Chrome has the most hits with 113.
# There were 266 page hits today, image requests account for 80.4511278195% of hits.
# Google Chrome has the most hits with 114.
# There were 267 page hits today, image requests account for 80.5243445693% of hits.
# Google Chrome has the most hits with 114.
# There were 268 page hits today, image requests account for 80.223880597% of hits.
# Google Chrome has the most hits with 115.
# There were 269 page hits today, image requests account for 80.2973977695% of hits.
# Google Chrome has the most hits with 116.
# There were 270 page hits today, image requests account for 80.3703703704% of hits.
# Google Chrome has the most hits with 117.
# There were 271 page hits today, image requests account for 80.442804428% of hits.
# Google Chrome has the most hits with 118.
# There were 272 page hits today, image requests account for 80.5147058824% of hits.
# Google Chrome has the most hits with 118.
# There were 273 page hits today, image requests account for 80.5860805861% of hits.
# Google Chrome has the most hits with 118.
# There were 274 page hits today, image requests account for 80.6569343066% of hits.
# Google Chrome has the most hits with 119.
# There were 275 page hits today, image requests account for 80.3636363636% of hits.
# Google Chrome has the most hits with 120.
# There were 276 page hits today, image requests account for 80.4347826087% of hits.
# Google Chrome has the most hits with 120.
# There were 277 page hits today, image requests account for 80.5054151625% of hits.
# Google Chrome has the most hits with 121.
# There were 278 page hits today, image requests account for 80.5755395683% of hits.
# Google Chrome has the most hits with 121.
# There were 279 page hits today, image requests account for 80.6451612903% of hits.
# Google Chrome has the most hits with 121.
# There were 280 page hits today, image requests account for 80.3571428571% of hits.
# Google Chrome has the most hits with 121.
# There were 281 page hits today, image requests account for 80.4270462633% of hits.
# Google Chrome has the most hits with 122.
# There were 282 page hits today, image requests account for 80.1418439716% of hits.
# Google Chrome has the most hits with 123.
# There were 283 page hits today, image requests account for 79.8586572438% of hits.
# Google Chrome has the most hits with 124.
# There were 284 page hits today, image requests account for 79.9295774648% of hits.
# Google Chrome has the most hits with 125.
# There were 285 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 125.
# There were 286 page hits today, image requests account for 80.0699300699% of hits.
# Google Chrome has the most hits with 125.
# There were 287 page hits today, image requests account for 80.1393728223% of hits.
# Google Chrome has the most hits with 125.
# There were 288 page hits today, image requests account for 80.2083333333% of hits.
# Google Chrome has the most hits with 125.
# There were 289 page hits today, image requests account for 79.9307958478% of hits.
# Google Chrome has the most hits with 125.
# There were 290 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 125.
# There were 291 page hits today, image requests account for 80.0687285223% of hits.
# Google Chrome has the most hits with 126.
# There were 292 page hits today, image requests account for 80.1369863014% of hits.
# Google Chrome has the most hits with 127.
# There were 293 page hits today, image requests account for 80.204778157% of hits.
# Google Chrome has the most hits with 128.
# There were 294 page hits today, image requests account for 79.9319727891% of hits.
# Google Chrome has the most hits with 129.
# There were 295 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 129.
# There were 296 page hits today, image requests account for 80.0675675676% of hits.
# Google Chrome has the most hits with 130.
# There were 297 page hits today, image requests account for 80.1346801347% of hits.
# Google Chrome has the most hits with 130.
# There were 298 page hits today, image requests account for 80.2013422819% of hits.
# Google Chrome has the most hits with 131.
# There were 299 page hits today, image requests account for 80.2675585284% of hits.
# Google Chrome has the most hits with 131.
# There were 300 page hits today, image requests account for 80.3333333333% of hits.
# Google Chrome has the most hits with 131.
# There were 301 page hits today, image requests account for 80.3986710963% of hits.
# Google Chrome has the most hits with 131.
# There were 302 page hits today, image requests account for 80.4635761589% of hits.
# Google Chrome has the most hits with 132.
# There were 303 page hits today, image requests account for 80.5280528053% of hits.
# Google Chrome has the most hits with 132.
# There were 304 page hits today, image requests account for 80.2631578947% of hits.
# Google Chrome has the most hits with 132.
# There were 305 page hits today, image requests account for 80.0% of hits.
# Google Chrome has the most hits with 133.
# There were 306 page hits today, image requests account for 80.0653594771% of hits.
# Google Chrome has the most hits with 133.
# There were 307 page hits today, image requests account for 79.8045602606% of hits.
# Google Chrome has the most hits with 133.
# There were 308 page hits today, image requests account for 79.8701298701% of hits.
# Google Chrome has the most hits with 134.
# There were 309 page hits today, image requests account for 79.6116504854% of hits.
# Google Chrome has the most hits with 134.
# There were 310 page hits today, image requests account for 79.3548387097% of hits.
# Google Chrome has the most hits with 135.
# There were 311 page hits today, image requests account for 79.0996784566% of hits.
# Google Chrome has the most hits with 135.
# There were 312 page hits today, image requests account for 78.8461538462% of hits.
# Google Chrome has the most hits with 136.
# There were 313 page hits today, image requests account for 78.9137380192% of hits.
# Google Chrome has the most hits with 137.
# There were 314 page hits today, image requests account for 78.9808917197% of hits.
# Google Chrome has the most hits with 137.
# There were 315 page hits today, image requests account for 79.0476190476% of hits.
# Google Chrome has the most hits with 137.
# There were 316 page hits today, image requests account for 79.1139240506% of hits.
# Google Chrome has the most hits with 138.
# There were 317 page hits today, image requests account for 78.8643533123% of hits.
# Google Chrome has the most hits with 139.
# There were 318 page hits today, image requests account for 78.9308176101% of hits.
# Google Chrome has the most hits with 140.
# There were 319 page hits today, image requests account for 78.9968652038% of hits.
# Google Chrome has the most hits with 140.
# There were 320 page hits today, image requests account for 78.75% of hits.
# Google Chrome has the most hits with 141.
# There were 321 page hits today, image requests account for 78.8161993769% of hits.
# Google Chrome has the most hits with 141.
# There were 322 page hits today, image requests account for 78.8819875776% of hits.
# Google Chrome has the most hits with 141.
# There were 323 page hits today, image requests account for 78.9473684211% of hits.
# Google Chrome has the most hits with 141.
# There were 324 page hits today, image requests account for 79.012345679% of hits.
# Google Chrome has the most hits with 142.
# There were 325 page hits today, image requests account for 79.0769230769% of hits.
# Google Chrome has the most hits with 142.
# There were 326 page hits today, image requests account for 79.1411042945% of hits.
# Google Chrome has the most hits with 142.
# There were 327 page hits today, image requests account for 79.2048929664% of hits.
# Google Chrome has the most hits with 142.
# There were 328 page hits today, image requests account for 79.2682926829% of hits.
# Google Chrome has the most hits with 143.
# There were 329 page hits today, image requests account for 79.0273556231% of hits.
# Google Chrome has the most hits with 143.
# There were 330 page hits today, image requests account for 79.0909090909% of hits.
# Google Chrome has the most hits with 143.
# There were 331 page hits today, image requests account for 78.8519637462% of hits.
# Google Chrome has the most hits with 143.
# There were 332 page hits today, image requests account for 78.9156626506% of hits.
# Google Chrome has the most hits with 143.
# There were 333 page hits today, image requests account for 78.978978979% of hits.
# Google Chrome has the most hits with 144.
# There were 334 page hits today, image requests account for 78.7425149701% of hits.
# Google Chrome has the most hits with 145.
# There were 335 page hits today, image requests account for 78.8059701493% of hits.
# Google Chrome has the most hits with 145.
# There were 336 page hits today, image requests account for 78.869047619% of hits.
# Google Chrome has the most hits with 146.
# There were 337 page hits today, image requests account for 78.9317507418% of hits.
# Google Chrome has the most hits with 146.
# There were 338 page hits today, image requests account for 78.9940828402% of hits.
# Google Chrome has the most hits with 147.
# There were 339 page hits today, image requests account for 79.0560471976% of hits.
# Google Chrome has the most hits with 147.
# There were 340 page hits today, image requests account for 78.8235294118% of hits.
# Google Chrome has the most hits with 148.
# There were 341 page hits today, image requests account for 78.5923753666% of hits.
# Google Chrome has the most hits with 148.
# There were 342 page hits today, image requests account for 78.6549707602% of hits.
# Google Chrome has the most hits with 148.
# There were 343 page hits today, image requests account for 78.7172011662% of hits.
# Google Chrome has the most hits with 149.
# There were 344 page hits today, image requests account for 78.7790697674% of hits.
# Google Chrome has the most hits with 149.
# There were 345 page hits today, image requests account for 78.5507246377% of hits.
# Google Chrome has the most hits with 149.
# There were 346 page hits today, image requests account for 78.612716763% of hits.
# Google Chrome has the most hits with 149.
# There were 347 page hits today, image requests account for 78.674351585% of hits.
# Google Chrome has the most hits with 149.
# There were 348 page hits today, image requests account for 78.7356321839% of hits.
# Google Chrome has the most hits with 150.
# There were 349 page hits today, image requests account for 78.7965616046% of hits.
# Google Chrome has the most hits with 150.
# There were 350 page hits today, image requests account for 78.8571428571% of hits.
# Google Chrome has the most hits with 151.
# There were 351 page hits today, image requests account for 78.9173789174% of hits.
# Google Chrome has the most hits with 151.
# There were 352 page hits today, image requests account for 78.9772727273% of hits.
# Google Chrome has the most hits with 152.
# There were 353 page hits today, image requests account for 79.0368271955% of hits.
# Google Chrome has the most hits with 153.
# There were 354 page hits today, image requests account for 79.0960451977% of hits.
# Google Chrome has the most hits with 153.
# There were 355 page hits today, image requests account for 79.1549295775% of hits.
# Google Chrome has the most hits with 153.
# There were 356 page hits today, image requests account for 79.2134831461% of hits.
# Google Chrome has the most hits with 154.
# There were 357 page hits today, image requests account for 79.2717086835% of hits.
# Google Chrome has the most hits with 154.
# There were 358 page hits today, image requests account for 79.3296089385% of hits.
# Google Chrome has the most hits with 154.
# There were 359 page hits today, image requests account for 79.3871866295% of hits.
# Google Chrome has the most hits with 155.
# There were 360 page hits today, image requests account for 79.1666666667% of hits.
# Google Chrome has the most hits with 155.
# There were 361 page hits today, image requests account for 79.2243767313% of hits.
# Google Chrome has the most hits with 156.
# There were 362 page hits today, image requests account for 79.2817679558% of hits.
# Google Chrome has the most hits with 157.
# There were 363 page hits today, image requests account for 79.3388429752% of hits.
# Google Chrome has the most hits with 158.
# There were 364 page hits today, image requests account for 79.3956043956% of hits.
# Google Chrome has the most hits with 158.
# There were 365 page hits today, image requests account for 79.4520547945% of hits.
# Google Chrome has the most hits with 158.
# There were 366 page hits today, image requests account for 79.5081967213% of hits.
# Google Chrome has the most hits with 159.
# There were 367 page hits today, image requests account for 79.5640326975% of hits.
# Google Chrome has the most hits with 159.
# There were 368 page hits today, image requests account for 79.6195652174% of hits.
# Google Chrome has the most hits with 159.
# There were 369 page hits today, image requests account for 79.4037940379% of hits.
# Google Chrome has the most hits with 159.
# There were 370 page hits today, image requests account for 79.1891891892% of hits.
# Google Chrome has the most hits with 160.
# There were 371 page hits today, image requests account for 78.9757412399% of hits.
# Google Chrome has the most hits with 160.
# There were 372 page hits today, image requests account for 79.0322580645% of hits.
# Google Chrome has the most hits with 160.
# There were 373 page hits today, image requests account for 79.0884718499% of hits.
# Google Chrome has the most hits with 161.
# There were 374 page hits today, image requests account for 79.1443850267% of hits.
# Google Chrome has the most hits with 162.
# There were 375 page hits today, image requests account for 79.2% of hits.
# Google Chrome has the most hits with 163.
# There were 376 page hits today, image requests account for 79.2553191489% of hits.
# Google Chrome has the most hits with 163.
# There were 377 page hits today, image requests account for 79.3103448276% of hits.
# Google Chrome has the most hits with 164.
# There were 378 page hits today, image requests account for 79.3650793651% of hits.
# Google Chrome has the most hits with 164.
# There were 379 page hits today, image requests account for 79.419525066% of hits.
# Google Chrome has the most hits with 164.
# There were 380 page hits today, image requests account for 79.2105263158% of hits.
# Google Chrome has the most hits with 164.
# There were 381 page hits today, image requests account for 79.0026246719% of hits.
# Google Chrome has the most hits with 164.
# There were 382 page hits today, image requests account for 79.057591623% of hits.
# Google Chrome has the most hits with 164.
# There were 383 page hits today, image requests account for 79.1122715405% of hits.
# Google Chrome has the most hits with 165.
# There were 384 page hits today, image requests account for 79.1666666667% of hits.
# Google Chrome has the most hits with 166.
# There were 385 page hits today, image requests account for 79.2207792208% of hits.
# Google Chrome has the most hits with 166.
# There were 386 page hits today, image requests account for 79.274611399% of hits.
# Google Chrome has the most hits with 167.
# ...
# There were 9876 page hits today, image requests account for 78.7970838396% of hits.
# Google Chrome has the most hits with 3986.
# There were 9877 page hits today, image requests account for 78.7992305356% of hits.
# Google Chrome has the most hits with 3987.
# There were 9878 page hits today, image requests account for 78.8013767969% of hits.
# Google Chrome has the most hits with 3987.
# There were 9879 page hits today, image requests account for 78.8035226237% of hits.
# Google Chrome has the most hits with 3988.
# There were 9880 page hits today, image requests account for 78.8056680162% of hits.
# Google Chrome has the most hits with 3988.
# There were 9881 page hits today, image requests account for 78.8078129744% of hits.
# Google Chrome has the most hits with 3989.
# There were 9882 page hits today, image requests account for 78.8099574985% of hits.
# Google Chrome has the most hits with 3989.
# There were 9883 page hits today, image requests account for 78.8019832035% of hits.
# Google Chrome has the most hits with 3989.
# There were 9884 page hits today, image requests account for 78.8041278834% of hits.
# Google Chrome has the most hits with 3990.
# There were 9885 page hits today, image requests account for 78.8062721295% of hits.
# Google Chrome has the most hits with 3990.
# There were 9886 page hits today, image requests account for 78.8084159417% of hits.
# Google Chrome has the most hits with 3991.
# There were 9887 page hits today, image requests account for 78.8105593203% of hits.
# Google Chrome has the most hits with 3991.
# There were 9888 page hits today, image requests account for 78.8127022654% of hits.
# Google Chrome has the most hits with 3991.
# There were 9889 page hits today, image requests account for 78.814844777% of hits.
# Google Chrome has the most hits with 3991.
# There were 9890 page hits today, image requests account for 78.806875632% of hits.
# Google Chrome has the most hits with 3991.
# There were 9891 page hits today, image requests account for 78.7989080983% of hits.
# Google Chrome has the most hits with 3992.
# There were 9892 page hits today, image requests account for 78.8010513546% of hits.
# Google Chrome has the most hits with 3992.
# There were 9893 page hits today, image requests account for 78.8031941777% of hits.
# Google Chrome has the most hits with 3992.
# There were 9894 page hits today, image requests account for 78.8053365676% of hits.
# Google Chrome has the most hits with 3993.
# There were 9895 page hits today, image requests account for 78.8074785245% of hits.
# Google Chrome has the most hits with 3993.
# There were 9896 page hits today, image requests account for 78.8096200485% of hits.
# Google Chrome has the most hits with 3993.
# There were 9897 page hits today, image requests account for 78.8117611397% of hits.
# Google Chrome has the most hits with 3993.
# There were 9898 page hits today, image requests account for 78.8139017983% of hits.
# Google Chrome has the most hits with 3993.
# There were 9899 page hits today, image requests account for 78.8160420244% of hits.
# Google Chrome has the most hits with 3993.
# There were 9900 page hits today, image requests account for 78.8080808081% of hits.
# Google Chrome has the most hits with 3993.
# There were 9901 page hits today, image requests account for 78.8102211898% of hits.
# Google Chrome has the most hits with 3993.
# There were 9902 page hits today, image requests account for 78.8123611392% of hits.
# Google Chrome has the most hits with 3993.
# There were 9903 page hits today, image requests account for 78.8145006564% of hits.
# Google Chrome has the most hits with 3993.
# There were 9904 page hits today, image requests account for 78.8166397415% of hits.
# Google Chrome has the most hits with 3993.
# There were 9905 page hits today, image requests account for 78.8187783948% of hits.
# Google Chrome has the most hits with 3993.
# There were 9906 page hits today, image requests account for 78.8209166162% of hits.
# Google Chrome has the most hits with 3993.
# There were 9907 page hits today, image requests account for 78.823054406% of hits.
# Google Chrome has the most hits with 3994.
# There were 9908 page hits today, image requests account for 78.81509891% of hits.
# Google Chrome has the most hits with 3995.
# There were 9909 page hits today, image requests account for 78.8172368554% of hits.
# Google Chrome has the most hits with 3996.
# There were 9910 page hits today, image requests account for 78.8193743693% of hits.
# Google Chrome has the most hits with 3997.
# There were 9911 page hits today, image requests account for 78.8215114519% of hits.
# Google Chrome has the most hits with 3998.
# There were 9912 page hits today, image requests account for 78.813559322% of hits.
# Google Chrome has the most hits with 3999.
# There were 9913 page hits today, image requests account for 78.8056087965% of hits.
# Google Chrome has the most hits with 4000.
# There were 9914 page hits today, image requests account for 78.7976598749% of hits.
# Google Chrome has the most hits with 4001.
# There were 9915 page hits today, image requests account for 78.7997982854% of hits.
# Google Chrome has the most hits with 4001.
# There were 9916 page hits today, image requests account for 78.8019362646% of hits.
# Google Chrome has the most hits with 4002.
# There were 9917 page hits today, image requests account for 78.8040738126% of hits.
# Google Chrome has the most hits with 4003.
# There were 9918 page hits today, image requests account for 78.7961282517% of hits.
# Google Chrome has the most hits with 4004.
# There were 9919 page hits today, image requests account for 78.7982659542% of hits.
# Google Chrome has the most hits with 4005.
# There were 9920 page hits today, image requests account for 78.8004032258% of hits.
# Google Chrome has the most hits with 4006.
# There were 9921 page hits today, image requests account for 78.7924604375% of hits.
# Google Chrome has the most hits with 4007.
# There were 9922 page hits today, image requests account for 78.7945978633% of hits.
# Google Chrome has the most hits with 4007.
# There were 9923 page hits today, image requests account for 78.7967348584% of hits.
# Google Chrome has the most hits with 4008.
# There were 9924 page hits today, image requests account for 78.7988714228% of hits.
# Google Chrome has the most hits with 4009.
# There were 9925 page hits today, image requests account for 78.8010075567% of hits.
# Google Chrome has the most hits with 4009.
# There were 9926 page hits today, image requests account for 78.8031432601% of hits.
# Google Chrome has the most hits with 4009.
# There were 9927 page hits today, image requests account for 78.8052785333% of hits.
# Google Chrome has the most hits with 4009.
# There were 9928 page hits today, image requests account for 78.8074133763% of hits.
# Google Chrome has the most hits with 4010.
# There were 9929 page hits today, image requests account for 78.8095477893% of hits.
# Google Chrome has the most hits with 4011.
# There were 9930 page hits today, image requests account for 78.8116817724% of hits.
# Google Chrome has the most hits with 4011.
# There were 9931 page hits today, image requests account for 78.8138153257% of hits.
# Google Chrome has the most hits with 4012.
# There were 9932 page hits today, image requests account for 78.8159484495% of hits.
# Google Chrome has the most hits with 4012.
# There were 9933 page hits today, image requests account for 78.8180811437% of hits.
# Google Chrome has the most hits with 4012.
# There were 9934 page hits today, image requests account for 78.8202134085% of hits.
# Google Chrome has the most hits with 4013.
# There were 9935 page hits today, image requests account for 78.8122798188% of hits.
# Google Chrome has the most hits with 4013.
# There were 9936 page hits today, image requests account for 78.8144122383% of hits.
# Google Chrome has the most hits with 4013.
# There were 9937 page hits today, image requests account for 78.8165442286% of hits.
# Google Chrome has the most hits with 4014.
# There were 9938 page hits today, image requests account for 78.8086134031% of hits.
# Google Chrome has the most hits with 4014.
# There were 9939 page hits today, image requests account for 78.8107455478% of hits.
# Google Chrome has the most hits with 4015.
# There were 9940 page hits today, image requests account for 78.8128772636% of hits.
# Google Chrome has the most hits with 4016.
# There were 9941 page hits today, image requests account for 78.8150085504% of hits.
# Google Chrome has the most hits with 4016.
# There were 9942 page hits today, image requests account for 78.8070810702% of hits.
# Google Chrome has the most hits with 4016.
# There were 9943 page hits today, image requests account for 78.8092125113% of hits.
# Google Chrome has the most hits with 4017.
# There were 9944 page hits today, image requests account for 78.8113435237% of hits.
# Google Chrome has the most hits with 4017.
# There were 9945 page hits today, image requests account for 78.8134741076% of hits.
# Google Chrome has the most hits with 4018.
# There were 9946 page hits today, image requests account for 78.8055499698% of hits.
# Google Chrome has the most hits with 4018.
# There were 9947 page hits today, image requests account for 78.8076807078% of hits.
# Google Chrome has the most hits with 4019.
# There were 9948 page hits today, image requests account for 78.8098110173% of hits.
# Google Chrome has the most hits with 4019.
# There were 9949 page hits today, image requests account for 78.8119408986% of hits.
# Google Chrome has the most hits with 4019.
# There were 9950 page hits today, image requests account for 78.8140703518% of hits.
# Google Chrome has the most hits with 4020.
# There were 9951 page hits today, image requests account for 78.8161993769% of hits.
# Google Chrome has the most hits with 4020.
# There were 9952 page hits today, image requests account for 78.8082797428% of hits.
# Google Chrome has the most hits with 4021.
# There were 9953 page hits today, image requests account for 78.8003617% of hits.
# Google Chrome has the most hits with 4022.
# There were 9954 page hits today, image requests account for 78.8024914607% of hits.
# Google Chrome has the most hits with 4022.
# There were 9955 page hits today, image requests account for 78.7945755902% of hits.
# Google Chrome has the most hits with 4023.
# There were 9956 page hits today, image requests account for 78.7967055042% of hits.
# Google Chrome has the most hits with 4024.
# There were 9957 page hits today, image requests account for 78.7988349905% of hits.
# Google Chrome has the most hits with 4024.
# There were 9958 page hits today, image requests account for 78.800964049% of hits.
# Google Chrome has the most hits with 4024.
# There were 9959 page hits today, image requests account for 78.80309268% of hits.
# Google Chrome has the most hits with 4024.
# There were 9960 page hits today, image requests account for 78.8052208835% of hits.
# Google Chrome has the most hits with 4024.
# There were 9961 page hits today, image requests account for 78.8073486598% of hits.
# Google Chrome has the most hits with 4025.
# There were 9962 page hits today, image requests account for 78.7994378639% of hits.
# Google Chrome has the most hits with 4026.
# There were 9963 page hits today, image requests account for 78.8015657934% of hits.
# Google Chrome has the most hits with 4027.
# There were 9964 page hits today, image requests account for 78.8036932959% of hits.
# Google Chrome has the most hits with 4027.
# There were 9965 page hits today, image requests account for 78.7957852484% of hits.
# Google Chrome has the most hits with 4027.
# There were 9966 page hits today, image requests account for 78.7878787879% of hits.
# Google Chrome has the most hits with 4028.
# There were 9967 page hits today, image requests account for 78.7900070232% of hits.
# Google Chrome has the most hits with 4028.
# There were 9968 page hits today, image requests account for 78.7921348315% of hits.
# Google Chrome has the most hits with 4029.
# There were 9969 page hits today, image requests account for 78.7942622129% of hits.
# Google Chrome has the most hits with 4029.
# There were 9970 page hits today, image requests account for 78.7963891675% of hits.
# Google Chrome has the most hits with 4029.
# There were 9971 page hits today, image requests account for 78.7884866112% of hits.
# Google Chrome has the most hits with 4029.
# There were 9972 page hits today, image requests account for 78.7805856398% of hits.
# Google Chrome has the most hits with 4030.
# There were 9973 page hits today, image requests account for 78.782713326% of hits.
# Google Chrome has the most hits with 4031.
# There were 9974 page hits today, image requests account for 78.7748145177% of hits.
# Google Chrome has the most hits with 4031.
# There were 9975 page hits today, image requests account for 78.7769423559% of hits.
# Google Chrome has the most hits with 4032.
# There were 9976 page hits today, image requests account for 78.7790697674% of hits.
# Google Chrome has the most hits with 4032.
# There were 9977 page hits today, image requests account for 78.7811967525% of hits.
# Google Chrome has the most hits with 4032.
# There were 9978 page hits today, image requests account for 78.7833233113% of hits.
# Google Chrome has the most hits with 4033.
# There were 9979 page hits today, image requests account for 78.7754283996% of hits.
# Google Chrome has the most hits with 4034.
# There were 9980 page hits today, image requests account for 78.7775551102% of hits.
# Google Chrome has the most hits with 4034.
# There were 9981 page hits today, image requests account for 78.7696623585% of hits.
# Google Chrome has the most hits with 4035.
# There were 9982 page hits today, image requests account for 78.7717892206% of hits.
# Google Chrome has the most hits with 4035.
# There were 9983 page hits today, image requests account for 78.7739156566% of hits.
# Google Chrome has the most hits with 4035.
# There were 9984 page hits today, image requests account for 78.7760416667% of hits.
# Google Chrome has the most hits with 4035.
# There were 9985 page hits today, image requests account for 78.7781672509% of hits.
# Google Chrome has the most hits with 4035.
# There were 9986 page hits today, image requests account for 78.7802924094% of hits.
# Google Chrome has the most hits with 4036.
# There were 9987 page hits today, image requests account for 78.7824171423% of hits.
# Google Chrome has the most hits with 4036.
# There were 9988 page hits today, image requests account for 78.7845414497% of hits.
# Google Chrome has the most hits with 4036.
# There were 9989 page hits today, image requests account for 78.7866653319% of hits.
# Google Chrome has the most hits with 4037.
# There were 9990 page hits today, image requests account for 78.7787787788% of hits.
# Google Chrome has the most hits with 4038.
# There were 9991 page hits today, image requests account for 78.7809028125% of hits.
# Google Chrome has the most hits with 4038.
# There were 9992 page hits today, image requests account for 78.7730184147% of hits.
# Google Chrome has the most hits with 4039.
# There were 9993 page hits today, image requests account for 78.7751425998% of hits.
# Google Chrome has the most hits with 4040.
# There were 9994 page hits today, image requests account for 78.7772663598% of hits.
# Google Chrome has the most hits with 4041.
# There were 9995 page hits today, image requests account for 78.7793896948% of hits.
# Google Chrome has the most hits with 4041.
# There were 9996 page hits today, image requests account for 78.781512605% of hits.
# Google Chrome has the most hits with 4041.
# There were 9997 page hits today, image requests account for 78.7836350905% of hits.
# Google Chrome has the most hits with 4042.
# There were 9998 page hits today, image requests account for 78.775755151% of hits.
# Google Chrome has the most hits with 4042.
# There were 9999 page hits today, image requests account for 78.7778777878% of hits.
# Google Chrome has the most hits with 4042.
# There were 10000 page hits today, image requests account for 78.77% of hits.
# Google Chrome has the most hits with 4042.
